# %% [markdown]
# # Thesis Codes  by Korkut Anapa

# %% [markdown]
# #  CLEANING CYCLE DESIGNER BY GOAL PROGRAMMING

# %% [markdown]
# ## Optimization Model
# Create a software that can design a cycle according to customer preferences

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
from catboost import CatBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from numpy import mean
from numpy import std
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import StackingRegressor
from matplotlib import pyplot
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import ElasticNetCV, ElasticNet
from sklearn.compose import make_column_selector as selector
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.cross_decomposition import PLSRegression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
from catboost import CatBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import StackingRegressor
from matplotlib import pyplot
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import ElasticNetCV, ElasticNet
from sklearn.compose import make_column_selector as selector

# %%
df_ref = pd.read_excel('D:/THESIS_DATA/ANALYSIS_DATA_THESIS/DB_SO_60.xlsx')

# %%
XX_all=['1OYSum of kapalı' , '1OYSum of SURE' , '1OYSum of CIRC_TIME' , '1OYSum of WI' , '1OYMax of DEVIR',
      '1OYMax of TEMP' , '1OYSum of ALT_C' , '1OYSum of ÜST_C' , '1OYSum of TEPE_C' , '1OYSum of ZONE_C' , '1OYSum of BEKLEME' ,
      '1OYSum of FAN' , '1OYSum of KAPI ACMA' , '1OYSum of FAN / KLAPE' , '1OYSum of GAUDI_offset' ,
      '1OYSum of GAUDI_nonoffset' , '2AYSum of kapalı' , '2AYSum of SURE' , '2AYSum of CIRC_TIME' , '2AYSum of WI' ,
      '2AYMax of DEVIR' , '2AYMax of TEMP' , '2AYSum of ALT_C' , '2AYSum of ÜST_C' , '2AYSum of TEPE_C' , '2AYSum of ZONE_C' , 
      '2AYSum of BEKLEME' , '2AYSum of FAN' , '2AYSum of KAPI ACMA' , '2AYSum of FAN / KLAPE' , '2AYSum of GAUDI_offset' , 
      '2AYSum of GAUDI_nonoffset' , '3MFTSum of kapalı' , '3MFTSum of SURE' , '3MFTSum of CIRC_TIME' , '3MFTSum of WI' ,
      '3MFTMax of DEVIR' , '3MFTMax of TEMP' , '3MFTSum of ALT_C' , '3MFTSum of ÜST_C' , '3MFTSum of TEPE_C' , 
      '3MFTSum of ZONE_C' , '3MFTSum of BEKLEME' , '3MFTSum of FAN', '3MFTSum of KAPI ACMA' , '3MFTSum of FAN / KLAPE' , 
      '3MFTSum of GAUDI_offset' , '3MFTSum of GAUDI_nonoffset' , '4SGDSum of kapalı' , '4SGDSum of SURE' , 
      '4SGDSum of CIRC_TIME', '4SGDSum of WI' , '4SGDMax of DEVIR' , '4SGDMax of TEMP' , '4SGDSum of ALT_C' , 
      '4SGDSum of ÜST_C' , '4SGDSum of TEPE_C' , '4SGDSum of ZONE_C' , '4SGDSum of BEKLEME' , '4SGDSum of FAN' , 
      '4SGDSum of KAPI ACMA' , '4SGDSum of FAN / KLAPE' , '4SGDSum of GAUDI_offset' , '4SGDSum of GAUDI_nonoffset' , 
      '5ERSum of kapalı' , '5ERSum of SURE' , '5ERSum of CIRC_TIME' , '5ERSum of WI' , '5ERMax of DEVIR' , '5ERMax of TEMP' ,
      '5ERSum of ALT_C' , '5ERSum of ÜST_C' , '5ERSum of TEPE_C' , '5ERSum of ZONE_C' , '5ERSum of BEKLEME' ,
      '5ERSum of FAN' , '5ERSum of KAPI ACMA' , '5ERSum of FAN / KLAPE' , '5ERSum of GAUDI_offset' , 
      '5ERSum of GAUDI_nonoffset' , '6SCD1Sum of kapalı' , '6SCD1Sum of SURE' , '6SCD1Sum of CIRC_TIME' , '6SCD1Sum of WI' , 
      '6SCD1Max of DEVIR' , '6SCD1Max of TEMP' , '6SCD1Sum of ALT_C' , '6SCD1Sum of ÜST_C' , '6SCD1Sum of TEPE_C' , 
      '6SCD1Sum of ZONE_C' , '6SCD1Sum of BEKLEME' , '6SCD1Sum of FAN' , '6SCD1Sum of KAPI ACMA' , '6SCD1Sum of FAN / KLAPE' ,
      '6SCD1Sum of GAUDI_offset' , '6SCD1Sum of GAUDI_nonoffset' , '7SCD2Sum of kapalı' , '7SCD2Sum of SURE' , 
      '7SCD2Sum of CIRC_TIME' , '7SCD2Sum of WI' , '7SCD2Max of DEVIR' , '7SCD2Max of TEMP' , '7SCD2Sum of ALT_C' , 
      '7SCD2Sum of ÜST_C' , '7SCD2Sum of TEPE_C' , '7SCD2Sum of ZONE_C' , '7SCD2Sum of BEKLEME' , '7SCD2Sum of FAN' , 
      '7SCD2Sum of KAPI ACMA' , '7SCD2Sum of FAN / KLAPE' , '7SCD2Sum of GAUDI_offset' , '7SCD2Sum of GAUDI_nonoffset' , 
      '8DSBSum of kapalı' , '8DSBSum of SURE' , '8DSBSum of CIRC_TIME' , '8DSBSum of WI' , '8DSBMax of DEVIR' , 
      '8DSBMax of TEMP' , '8DSBSum of ALT_C' , '8DSBSum of ÜST_C', '8DSBSum of TEPE_C' , '8DSBSum of ZONE_C' ,
      '8DSBSum of BEKLEME' , '8DSBSum of FAN' , '8DSBSum of KAPI ACMA' , '8DSBSum of FAN / KLAPE' , '8DSBSum of GAUDI_offset' ,
      '8DSBSum of GAUDI_nonoffset', '9RYSum of kapalı' , '9RYSum of SURE' , '9RYSum of CIRC_TIME' , '9RYSum of WI' , 
      '9RYMax of DEVIR' , '9RYMax of TEMP' , '9RYSum of ALT_C' , '9RYSum of ÜST_C', '9RYSum of TEPE_C' , '9RYSum of ZONE_C' ,
      '9RYSum of BEKLEME' , '9RYSum of FAN' , '9RYSum of KAPI ACMA' , '9RYSum of FAN / KLAPE' , '9RYSum of GAUDI_offset' ,
      '9RYSum of GAUDI_nonoffset' , '10KUSum of kapalı' , '10KUSum of SURE' , '10KUSum of CIRC_TIME' , '10KUSum of WI' , 
      '10KUMax of DEVIR' , '10KUMax of TEMP' , '10KUSum of ALT_C' , '10KUSum of ÜST_C', '10KUSum of TEPE_C' ,
      '10KUSum of ZONE_C' , '10KUSum of BEKLEME' , '10KUSum of FAN' , '10KUSum of KAPI ACMA' , '10KUSum of FAN / KLAPE' ,
      '10KUSum of GAUDI_offset', '10KUSum of GAUDI_nonoffset']

# %%
df=df_ref[XX_all]

# %%
df
# Out:
#      1OYSum of kapalı  1OYSum of SURE  1OYSum of CIRC_TIME  1OYSum of WI  \
# 0                   0              24                   21           4.0
# 1                   0              21                   18           4.0
# 2                   0              21                   18           4.0
# 3                   2              48                   43           4.8
# 4                   3              49                   44           4.8
# ..                ...             ...                  ...           ...
# 149                 0              23                   20           4.6
# 150                 0              19                   16           4.0
# 151                 0               8                    6           3.5
# 152                 0              19                   16           4.0
# 153                 0              24                   21           4.0
#
#      1OYMax of DEVIR  1OYMax of TEMP  1OYSum of ALT_C  1OYSum of ÜST_C  \
# ...

# %%
y_CPI = df_ref['CPI']
y_DPI = df_ref['DPI']
y_EC_D =df_ref['EC']
y_T_D =df_ref['T']

# %%
y_CPI.describe()
# Out:
# count    154.000000
# mean       3.287778
# std        0.226735
# min        2.290000
# 25%        3.274000
# 50%        3.327080
# 75%        3.370500
# max        3.580000
# Name: CPI, dtype: float64

# %%
y_DPI.describe()
# Out:
# count    154.000000
# mean      79.913332
# std       15.151414
# min       15.000000
# 25%       81.000000
# 50%       84.000000
# 75%       86.095376
# max       92.301325
# Name: DPI, dtype: float64

# %%
y_EC_D.describe()
# Out:
# count    154.000000
# mean       0.874302
# std        0.149146
# min        0.500000
# 25%        0.800500
# 50%        0.856667
# 75%        0.949250
# max        1.220000
# Name: EC, dtype: float64

# %%
y_T_D.describe()
# Out:
# count    154.000000
# mean     206.053301
# std       66.297071
# min       30.000000
# 25%      205.000000
# 50%      227.333333
# 75%      243.562500
# max      297.000000
# Name: T, dtype: float64

# %% [markdown]
# ## Variance Analysis

# %%
from sklearn.feature_selection import VarianceThreshold

var_thr = VarianceThreshold(threshold = 0.05) #Removing both constant and quasi-constant
var_thr.fit(df)

var_thr.get_support()
concol = [column for column in df.columns 
          if column not in df.columns[var_thr.get_support()]]
df_ver_1=df.drop(concol,axis=1)
df_ver_1
# Out:
#      1OYSum of kapalı  1OYSum of SURE  1OYSum of CIRC_TIME  1OYSum of WI  \
# 0                   0              24                   21           4.0
# 1                   0              21                   18           4.0
# 2                   0              21                   18           4.0
# 3                   2              48                   43           4.8
# 4                   3              49                   44           4.8
# ..                ...             ...                  ...           ...
# 149                 0              23                   20           4.6
# 150                 0              19                   16           4.0
# 151                 0               8                    6           3.5
# 152                 0              19                   16           4.0
# 153                 0              24                   21           4.0
#
#      1OYMax of DEVIR  1OYMax of TEMP  1OYSum of ALT_C  1OYSum of ÜST_C  \
# ...

# %%
correlation_matrix=df_ver_1.corr()
correlated_features = set()

# %%
threshold = 0.999

for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > threshold:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)

# %%
df_ver_3 = df_ver_1.drop(labels=correlated_features, axis=1)
df_ver_3
# Out:
#      1OYSum of kapalı  1OYSum of SURE  1OYSum of CIRC_TIME  1OYSum of WI  \
# 0                   0              24                   21           4.0
# 1                   0              21                   18           4.0
# 2                   0              21                   18           4.0
# 3                   2              48                   43           4.8
# 4                   3              49                   44           4.8
# ..                ...             ...                  ...           ...
# 149                 0              23                   20           4.6
# 150                 0              19                   16           4.0
# 151                 0               8                    6           3.5
# 152                 0              19                   16           4.0
# 153                 0              24                   21           4.0
#
#      1OYMax of DEVIR  1OYMax of TEMP  1OYSum of ALT_C  1OYSum of ÜST_C  \
# ...

# %%
# Analysis of a Matrix 
# input matrix name
matrix_name= df_ver_3


X_matrix = matrix_name.to_numpy()
rank = np.linalg.matrix_rank(X_matrix)
print("\nRank:", rank)
XMT=np.transpose(X_matrix)
XTX=np.dot(XMT,X_matrix)
det = np.linalg.det(XTX)
print("\nDeterminant:", det)
Co=np.linalg.cond(X_matrix)
print("\nCondition Number :", Co)
# Out:
# Rank: 47
#
# Determinant: 6.912715513942465e+112
#
# Condition Number : 882600.4776927123

# %%
df_ver_3.columns
# Out:
# Index(['1OYSum of kapalı', '1OYSum of SURE', '1OYSum of CIRC_TIME',
#        '1OYSum of WI', '1OYMax of DEVIR', '1OYMax of TEMP', '1OYSum of ALT_C',
#        '1OYSum of ÜST_C', '1OYSum of TEPE_C', '1OYSum of BEKLEME',
#        '2AYSum of kapalı', '2AYSum of SURE', '2AYSum of CIRC_TIME',
#        '2AYSum of WI', '2AYMax of DEVIR', '2AYMax of TEMP', '2AYSum of ALT_C',
#        '2AYSum of ÜST_C', '2AYSum of TEPE_C', '3MFTSum of SURE',
#        '3MFTSum of WI', '4SGDSum of SURE', '4SGDSum of CIRC_TIME',
#        '4SGDSum of WI', '4SGDMax of DEVIR', '4SGDSum of ALT_C',
#        '4SGDSum of ÜST_C', '4SGDSum of TEPE_C', '4SGDSum of BEKLEME',
#        '7SCD2Sum of kapalı', '7SCD2Sum of SURE', '7SCD2Sum of CIRC_TIME',
#        '7SCD2Sum of WI', '7SCD2Max of DEVIR', '7SCD2Max of TEMP',
#        '7SCD2Sum of ALT_C', '7SCD2Sum of ÜST_C', '7SCD2Sum of TEPE_C',
#        '7SCD2Sum of BEKLEME', '8DSBSum of kapalı', '8DSBMax of DEVIR',
# ...

# %%
df_ver_3
# Out:
#      1OYSum of kapalı  1OYSum of SURE  1OYSum of CIRC_TIME  1OYSum of WI  \
# 0                   0              24                   21           4.0
# 1                   0              21                   18           4.0
# 2                   0              21                   18           4.0
# 3                   2              48                   43           4.8
# 4                   3              49                   44           4.8
# ..                ...             ...                  ...           ...
# 149                 0              23                   20           4.6
# 150                 0              19                   16           4.0
# 151                 0               8                    6           3.5
# 152                 0              19                   16           4.0
# 153                 0              24                   21           4.0
#
#      1OYMax of DEVIR  1OYMax of TEMP  1OYSum of ALT_C  1OYSum of ÜST_C  \
# ...

# %%
outputs = [ y_CPI, y_DPI , y_EC_D, y_T_D]
X=df_ver_3
model = LinearRegression()
for y in outputs:
    model.fit(X, y)
    cv = RepeatedKFold(n_splits=5, n_repeats=3, random_state=79)
    scores1 = cross_val_score(model,X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
    scores3 = cross_val_score(model,X, y, scoring='r2', cv=cv, n_jobs=-1, error_score='raise')
    print(' %.2f %.0f' % (-mean(scores1), 100*mean(scores3)))
# Out:
#  0.14 -635
#  6.46 -396
#  0.07 1
#  5.40 91

# %%
outputs = [ y_CPI, y_DPI , y_EC_D, y_T_D]
X=df_ver_3
model = XGBRegressor(n_estimators=100, max_depth=7, eta=0.1, subsample=0.7, colsample_bytree=0.8)
for y in outputs:
    model.fit(X, y)
    cv = RepeatedKFold(n_splits=5, n_repeats=3, random_state=79)
    scores1 = cross_val_score(model,X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
    scores3 = cross_val_score(model,X, y, scoring='r2', cv=cv, n_jobs=-1, error_score='raise')
    print(' %.3f %.0f' % (-mean(scores1), 100*mean(scores3)))
# Out:
#  0.046 72
#  2.243 86
#  0.035 86
#  4.337 99

# %% [markdown]
# ## SELECTED INDEPENDENT VARIABLES AND MODELS

# %%
dt[cc]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5108\1077007883.py in <module>
# ----> 1 dt[cc]
#
# NameError: name 'dt' is not defined

# %%
from genetic_selection import GeneticSelectionCV
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
import numpy as np

X = df_ver_3
y = y_CPI
estimator = LinearRegression()
model = GeneticSelectionCV(
    estimator, cv=5, verbose=0,
    scoring="neg_mean_absolute_error", max_features=47,
    n_population=100, crossover_proba=0.5,
    mutation_proba=0.2, n_generations=50,
    crossover_independent_proba=0.5,
    mutation_independent_proba=0.04,
    tournament_size=3, n_gen_no_change=10,
    caching=True, n_jobs=-1)
model = model.fit(X, y)
print('Features:', X.columns[model.support_])
selected_columns=X.columns[model.support_]       
XX = X[selected_columns].copy()

# %%
selected_columns=['1OYSum of SURE', '1OYSum of CIRC_TIME', '1OYSum of WI',
       '1OYMax of TEMP', '1OYSum of ÜST_C', '2AYMax of TEMP',
       '2AYSum of ALT_C', '2AYSum of ÜST_C', '4SGDSum of CIRC_TIME',
       '4SGDSum of ALT_C', '4SGDSum of BEKLEME', '7SCD2Sum of kapalı',
       '7SCD2Sum of CIRC_TIME', '7SCD2Max of DEVIR', '7SCD2Max of TEMP',
       '10KUSum of SURE', '10KUSum of BEKLEME', '10KUSum of KAPI ACMA',
       '10KUSum of FAN / KLAPE']

# %%
XX=selected_columns
X=df_ver_3[XX]

# %%
model_CPI = LinearRegression()
model_CPI.fit(X, y_CPI)
cv = RepeatedKFold(n_splits=5, n_repeats=3, random_state=34)
scores1 = cross_val_score(model_CPI,X, y_CPI, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
scores2 = cross_val_score(model_CPI,X, y_CPI, scoring='neg_root_mean_squared_error', cv=cv, n_jobs=-1, error_score='raise')
scores3 = cross_val_score(model_CPI,X, y_CPI, scoring='r2', cv=cv, n_jobs=-1, error_score='raise')
scores4 = cross_val_score(model_CPI,X, y_CPI, scoring='explained_variance', cv=cv, n_jobs=-1, error_score='raise')
scores5 = cross_val_score(model_CPI,X, y_CPI, scoring='max_error', cv=cv, n_jobs=-1, error_score='raise')
print(' %.3f %.3f  %.3f %.3f %.3f' % (mean(scores1), mean(scores2), mean(scores3), mean(scores4), min(scores5)))
# Out:
#  -0.064 -0.089  0.618 0.637 -0.363

# %%
model_CPI.intercept_
# Out:
# -1.0010578718298908

# %%
model_CPI.coef_
# Out:
# array([-0.00121261, -0.02033681,  0.03721441,  0.00761785,  0.00904494,
#         0.00537508,  0.00627336, -0.00305054,  0.02655434, -0.0286675 ,
#        -0.07056082, -0.03818188,  0.01614929,  0.0005259 ,  0.03050513,
#         0.00417524, -0.00033662,  0.30787826,  0.0040947 ])

# %%
model_DPI = LinearRegression()
model_DPI.fit(X, y_DPI)
cv = RepeatedKFold(n_splits=5, n_repeats=3, random_state=81)
scores1 = cross_val_score(model_DPI,X, y_DPI, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
scores2 = cross_val_score(model_DPI,X, y_DPI, scoring='neg_root_mean_squared_error', cv=cv, n_jobs=-1, error_score='raise')
scores3 = cross_val_score(model_DPI,X, y_DPI, scoring='r2', cv=cv, n_jobs=-1, error_score='raise')
scores4 = cross_val_score(model_DPI,X, y_DPI, scoring='explained_variance', cv=cv, n_jobs=-1, error_score='raise')
scores5 = cross_val_score(model_DPI,X, y_DPI, scoring='max_error', cv=cv, n_jobs=-1, error_score='raise')
print(' %.3f %.3f  %.3f %.3f %.3f' % (mean(scores1), mean(scores2), mean(scores3), mean(scores4), min(scores5)))
# Out:
#  -3.967 -5.156  0.816 0.820 -19.323

# %%
model_DPI.intercept_
# Out:
# -145.14059392339283

# %%
model_DPI.coef_
# Out:
# array([-0.14958247, -0.89160867,  3.17504494,  0.30587708,  0.20532355,
#         0.35702865,  0.84713918, -0.33721847,  2.62573268, -2.98823593,
#        -4.39779955, -1.93167294,  0.95224537,  0.02263052,  1.45537714,
#         0.19512384, -0.03816588, 15.78574794,  0.23743756])

# %%
model_EC = LinearRegression()
model_EC.fit(X, y_EC_D)
cv = RepeatedKFold(n_splits=5, n_repeats=3, random_state=1425)
scores1 = cross_val_score(model_EC,X, y_EC_D, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
scores2 = cross_val_score(model_EC,X, y_EC_D, scoring='neg_root_mean_squared_error', cv=cv, n_jobs=-1, error_score='raise')
scores3 = cross_val_score(model_EC,X, y_EC_D, scoring='r2', cv=cv, n_jobs=-1, error_score='raise')
scores4 = cross_val_score(model_EC,X, y_EC_D, scoring='explained_variance', cv=cv, n_jobs=-1, error_score='raise')
scores5 = cross_val_score(model_EC,X, y_EC_D, scoring='max_error', cv=cv, n_jobs=-1, error_score='raise')
print(' %.3f %.3f  %.3f %.3f %.3f' % (mean(scores1), mean(scores2), mean(scores3), mean(scores4), min(scores5)))
# Out:
#  -0.043 -0.053  0.865 0.869 -0.186

# %%
model_EC.intercept_
# Out:
# -0.6490631613642062

# %%
model_EC.coef_
# Out:
# array([-1.60247176e-03, -5.14721659e-03,  2.51863039e-02,  1.63195535e-03,
#        -2.94908636e-03,  4.38610141e-03, -1.39449566e-03,  1.26652009e-03,
#         4.27060729e-03,  2.58071965e-02, -4.44590951e-02, -2.82568493e-02,
#         4.41765686e-03,  2.93091759e-05,  1.87427639e-02,  6.02841705e-04,
#        -2.14699719e-04,  5.98586873e-02,  7.38660817e-04])

# %%
model_T = LinearRegression()
model_T.fit(X, y_T_D)
cv = RepeatedKFold(n_splits=5, n_repeats=3, random_state=12)
scores1 = cross_val_score(model_T,X, y_T_D, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
scores2 = cross_val_score(model_T,X, y_T_D, scoring='neg_root_mean_squared_error', cv=cv, n_jobs=-1, error_score='raise')
scores3 = cross_val_score(model_T,X, y_T_D, scoring='r2', cv=cv, n_jobs=-1, error_score='raise')
scores4 = cross_val_score(model_T,X, y_T_D, scoring='explained_variance', cv=cv, n_jobs=-1, error_score='raise')
scores5 = cross_val_score(model_T,X, y_T_D, scoring='max_error', cv=cv, n_jobs=-1, error_score='raise')
print(' %.3f %.3f  %.3f %.3f %.3f' % (mean(scores1), mean(scores2), mean(scores3), mean(scores4), min(scores5)))
# Out:
#  -5.182 -7.221  0.984 0.984 -53.872

# %%
model_T.intercept_
# Out:
# -59.053374365611745

# %%
model_T.coef_
# Out:
# array([ 0.92475515,  0.81642581,  0.57169924, -0.02571971, -0.8904525 ,
#         0.16183313,  0.59293917,  0.22368522,  3.77837153, -3.26609359,
#        -3.87635421,  0.9268419 ,  0.6234016 ,  0.02311808,  0.0554219 ,
#         1.25648968, -0.20879479,  0.91046895, -0.09648523])

# %%
model_T
# Out:
# LinearRegression()

# %%
model_EC
# Out:
# LinearRegression()

# %%
model_CPI
# Out:
# LinearRegression()

# %%
model_DPI
# Out:
# LinearRegression()

# %%
df_base = pd.read_excel('D:/THESIS_DATA/ANALYSIS_DATA_THESIS/DB_SO_eco.xlsx')

# %%
X_base=df_base[selected_columns]

# %%
xl=[]
xu=[]

# %%
X=X_base
for term in X:
    xl.append(0.80*min(X_base[term]))
    xu.append(1.20*max(X_base[term]))

# %%
from pyomo.environ import *
from pyomo.opt import SolverFactory

# %%
opt = SolverFactory('ipopt')

# %%
opt = SolverFactory('cplex_direct')
# Create an object of a concrete model
model = ConcreteModel()
# Define the decision variables
model.x1 = Var(within = NonNegativeReals)
model.x2 = Var(within = NonNegativeReals)
model.x3 = Var(within = NonNegativeReals)
model.x4 = Var(within = NonNegativeReals)
model.x5 = Var(within = NonNegativeReals)
model.x6 = Var(within = NonNegativeReals)
model.x7 = Var(within = NonNegativeReals)
model.x8 = Var(within = NonNegativeReals)
model.x9 = Var(within = NonNegativeReals)
model.x10 = Var(within = NonNegativeReals)
model.x11 = Var(within = NonNegativeReals)
model.x12 = Var(within = NonNegativeReals)
model.x13 = Var(within = NonNegativeReals)
model.x14 = Var(within = NonNegativeReals)
model.x15 = Var(within = NonNegativeReals)
model.x16 = Var(within = NonNegativeReals)
model.x17 = Var(within = NonNegativeReals)
model.x18 = Var(within = NonNegativeReals)
model.x19 = Var(within = NonNegativeReals)
#model.x20 = Var(within = NonNegativeReals)
#model.x21 = Var(within = NonNegativeReals)
#model.x22 = Var(within = NonNegativeReals)
#model.x23 = Var(within = NonNegativeReals)


# Define the deviational variables
model.n1 = Var(within = NonNegativeReals)
model.p1 = Var(within = NonNegativeReals)
model.n2 = Var(within = NonNegativeReals)
model.p2 = Var(within = NonNegativeReals)
model.n3 = Var(within = NonNegativeReals)
model.p3 = Var(within = NonNegativeReals)
model.n4 = Var(within = NonNegativeReals)
model.p4 = Var(within = NonNegativeReals)

# %%
CPI0=model_CPI.intercept_
DPI0=model_DPI.intercept_
EC0=model_EC.intercept_
T0=model_T.intercept_

# %%
for i in range(1, 20):
    globals()[f"CPI{i}"] = model_CPI.coef_[i-1]
    globals()[f"DPI{i}"] = model_DPI.coef_[i-1]
    globals()[f"EC{i}"] = model_EC.coef_[i-1]
    globals()[f"T{i}"] = model_T.coef_[i-1]

# %%
CPI=3.30
DPI=80
EC=0.65
T=300

# %%
model.l=Var(within = NonNegativeReals)

# %%
# Define the objective function
model.obj = Objective(expr = model.l)

# Define the constraints
model.con1= Constraint(expr = (1 / CPI) * model.n1 <= model.l)
model.con2= Constraint(expr = (1 / DPI) * model.n2 <= model.l)
model.con3= Constraint(expr = (1 / EC) * model.p3 <= model.l)
model.con4= Constraint(expr = (1 / T) * model.p4 <= model.l)
model.con5 = Constraint(expr = CPI0 + CPI1*model.x1+CPI2*model.x2+CPI3*model.x3+CPI4*model.x4+CPI5*model.x5+CPI6*model.x6+
                                CPI7*model.x7+CPI8*model.x8+CPI9*model.x9+CPI10*model.x10+CPI11*model.x11+CPI12*model.x12+CPI13*model.x13+CPI14*model.x14+
                                CPI15*model.x15+CPI16*model.x16+CPI17*model.x17+CPI18*model.x18+CPI19*model.x19+model.n1 -model.p1 == CPI)
model.con6 = Constraint(expr = DPI0 + DPI1*model.x1+DPI2*model.x2+DPI3*model.x3+DPI4*model.x4+DPI5*model.x5+DPI6*model.x6+
                                DPI7*model.x7+DPI8*model.x8+DPI9*model.x9+DPI10*model.x10+DPI11*model.x11+DPI12*model.x12+DPI13*model.x13+DPI14*model.x14+
                                DPI15*model.x15+DPI16*model.x16+DPI17*model.x17+DPI18*model.x18+DPI19*model.x19+model.n2 -model.p2 == DPI)
model.con7= Constraint(expr = EC0 + EC1*model.x1+EC2*model.x2+EC3*model.x3+EC4*model.x4+EC5*model.x5+EC6*model.x6+
                                EC7*model.x7+EC8*model.x8+EC9*model.x9+EC10*model.x10+EC11*model.x11+EC12*model.x12+EC13*model.x13+EC14*model.x14+
                                EC15*model.x15+EC16*model.x16+EC17*model.x17+EC18*model.x18+EC19*model.x19+model.n3 -model.p3 == EC)
model.con8= Constraint(expr = T0 + T1*model.x1+T2*model.x2+T3*model.x3+T4*model.x4+T5*model.x5+T6*model.x6+
                                T7*model.x7+T8*model.x8+T9*model.x9+T10*model.x10+T11*model.x11+T12*model.x12+T13*model.x13+T14*model.x14+
                                T15*model.x15+T16*model.x16+T17*model.x17+T18*model.x18+T19*model.x19+model.n4 -model.p4 == T)
model.con9=Constraint(expr = model.x1>=xl[0])
model.con10=Constraint(expr = model.x1<=xu[0])
model.con11=Constraint(expr = model.x2>=xl[1])
model.con12=Constraint(expr = model.x2<=xu[1])
model.con13=Constraint(expr = model.x3>=xl[2])
model.con14=Constraint(expr = model.x3<=xu[2])
model.con15=Constraint(expr = model.x4>=xl[3])
model.con16=Constraint(expr = model.x4<=xu[3])
model.con17=Constraint(expr = model.x5>=xl[4])
model.con18=Constraint(expr = model.x5<=xu[4])
model.con19=Constraint(expr = model.x6>=xl[5])
model.con20=Constraint(expr = model.x6<=xu[5])
model.con21=Constraint(expr = model.x7>=xl[6])
model.con22=Constraint(expr = model.x7<=xu[6])
model.con23=Constraint(expr = model.x8>=xl[7])
model.con24=Constraint(expr = model.x8<=xu[7])
model.con25=Constraint(expr = model.x9>=xl[8])
model.con26=Constraint(expr = model.x9<=xu[8])
model.con27=Constraint(expr = model.x10>=xl[9])
model.con28=Constraint(expr = model.x10<=xu[9])
model.con29=Constraint(expr = model.x11>=xl[10])
model.con30=Constraint(expr = model.x11<=xu[10])
model.con31=Constraint(expr = model.x12>=xl[11])
model.con32=Constraint(expr = model.x12<=xu[11])
model.con33=Constraint(expr = model.x13>=xl[12])
model.con34=Constraint(expr = model.x13<=xu[12])
model.con35=Constraint(expr = model.x14>=xl[13])
model.con36=Constraint(expr = model.x14<=xu[13])
model.con37=Constraint(expr = model.x15>=xl[14])
model.con38=Constraint(expr = model.x15<=xu[14])
model.con39=Constraint(expr = model.x16>=xl[15])
model.con40=Constraint(expr = model.x16<=xu[15])
model.con41=Constraint(expr = model.x17>=xl[16])
model.con42=Constraint(expr = model.x17<=xu[16])
model.con43=Constraint(expr = model.x18>=xl[17])
model.con44=Constraint(expr = model.x18<=xu[17])
model.con45=Constraint(expr = model.x19>=xl[18])
model.con46=Constraint(expr = model.x19<=xu[18])
#model.con47=Constraint(expr = model.x20>=xl[19])
#model.con48=Constraint(expr = model.x20<=xu[19])
#model.con49=Constraint(expr = model.x21>=xl[20])
#model.con50=Constraint(expr = model.x21<=xu[20])
#model.con51=Constraint(expr = model.x22>=xl[21])
#model.con52=Constraint(expr = model.x22<=xu[21])
#model.con53=Constraint(expr = model.x23>=xl[22])
#model.con54=Constraint(expr = model.x23<=xu[22])

# Solve the Goal Programming problem
opt.solve(model)
# Out:
# {'Problem': [{'Name': '', 'Lower bound': 0.0, 'Upper bound': 0.0, 'Number of objectives': 1, 'Number of constraints': 46, 'Number of variables': 28, 'Number of binary variables': 0, 'Number of integer variables': 0, 'Number of continuous variables': 28, 'Number of nonzeros': None, 'Sense': 1}], 'Solver': [{'Name': 'CPLEX 22.1.0.0', 'Status': 'ok', 'Wallclock time': 0.04090428352355957, 'Termination condition': 'optimal'}], 'Solution': [OrderedDict([('number of solutions', 0), ('number of solutions displayed', 0)])]}

# %%
# Print the values of the decision variables

print("CPI_TARGET = ", CPI)
print("DPI_TARGET = ", DPI)
print("EC_TARGET = ", EC)
print("T_TARGET = ", T)

print("x1  =",model.x1.value)
print("x2  =",model.x2.value)
print("x3  =",model.x3.value)
print("x4  =",model.x4.value)
print("x5  =",model.x5.value)
print("x6  =",model.x6.value)
print("x7  =",model.x7.value)
print("x8  =",model.x8.value)
print("x9  =",model.x9.value)
print("x10  =",model.x10.value)
print("x11  =",model.x11.value)
print("x12  =",model.x12.value)
print("x13  =",model.x13.value)
print("x14  =",model.x14.value)
print("x15  =",model.x15.value)
print("x16  =",model.x16.value)
print("x17  =",model.x17.value)
print("x18  =",model.x18.value)
print("x19  =",model.x19.value)



# Print the achieved values for each goal
if model.n1.value > 0:
    print("The first goal is underachieved by ",model.n1.value)
elif model.p1.value > 0:
    print("The first goal is overachieved by ", model.p1.value)
else:
    print("The first goal is fully satisfied",CPI)


if model.n2.value > 0:
    print("The second goal is underachieved by ",model.n2.value)
elif model.p2.value > 0:
    print("The second goal is overachieved by ",model.p2.value)
else:
    print("The second goal is fully satisfied",DPI)

if model.n3.value > 0:
    print("The third goal is underachieved by ",model.n3.value)
elif model.p3.value > 0:
    print("The third goal is overachieved by ",model.p3.value)
else:
    print("The third goal is fully satisfied",EC)
    
    
if model.n4.value > 0:
    print("The fourth goal is underachieved by ",model.n4.value)
elif model.p4.value > 0:
    print("The fourth goal is overachieved by ",model.p4.value)
else:
    print("The fourth goal is fully satisfied",T)
# Out:
# CPI_TARGET =  3.3
# DPI_TARGET =  80
# EC_TARGET =  0.65
# T_TARGET =  300
# x1  = 34.4
# x2  = 32.0
# x3  = 3.2
# x4  = 64.8
# x5  = 8.933333333333334
# x6  = 40.0
# x7  = 27.348
# x8  = 19.832
# x9  = 9.600000000000001
# x10  = 1.6
# x11  = 0.0
# x12  = 3.2
# x13  = 31.2
# x14  = 2476.116056748527
# x15  = 47.83526596903424
# x16  = 65.60000000000001
# x17  = 64.0
# x18  = 1.2
# x19  = 0.0
# The first goal is fully satisfied 3.3
# The second goal is overachieved by  2.6676004987182687
# The third goal is fully satisfied 0.65
# The fourth goal is underachieved by  98.27070552366335
